# %%
import pandas as pd
from matplotlib import pyplot as plt
from glob import glob
from scipy.stats import mannwhitneyu, ttest_ind
from tqdm import tqdm
import numpy as np
import math
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %%
def load_ipeds_unis(fname='../../data/IPEDS/hd2020.csv', encoding='cp1252'):
    return pd.read_csv(fname, encoding=encoding)

def filter_only_rs_and_las(unis):
    unis = unis[unis['C18BASIC'].apply(lambda x: x in [15, 16, 17, 21, 22])]
    unis['Y']  = unis['C18BASIC'].apply(lambda x: 'liberal_arts' if x in [21, 22] else 'research')
    return unis

unis     = load_ipeds_unis()

# %%
data = pd.read_csv('../../data/fall_staff/s2022_oc.csv')

# %%
data['HRTOTLT']
# Out:
# 0         975
# 1         374
# 2         369
# 3           5
# 4          18
#          ...
# 183553      5
# 183554      6
# 183555      2
# 183556    130
# 183557    130
# Name: HRTOTLT, Length: 183558, dtype: int64

# %%
merged = pd.merge(unis, data, left_on='UNITID', right_on='UNITID')

# %%
merged.head()
# Out:
#    UNITID                    INSTNM IALIAS                  ADDR    CITY  \
# 0  100654  Alabama A & M University   AAMU  4900 Meridian Street  Normal
# 1  100654  Alabama A & M University   AAMU  4900 Meridian Street  Normal
# 2  100654  Alabama A & M University   AAMU  4900 Meridian Street  Normal
# 3  100654  Alabama A & M University   AAMU  4900 Meridian Street  Normal
# 4  100654  Alabama A & M University   AAMU  4900 Meridian Street  Normal
#
#   STABBR    ZIP  FIPS  OBEREG                   CHFNM  ... XHRUNKNM HRUNKNM  \
# 0     AL  35762     1       5  Dr. Andrew Hugine, Jr.  ...        R       3
# 1     AL  35762     1       5  Dr. Andrew Hugine, Jr.  ...        R       2
# 2     AL  35762     1       5  Dr. Andrew Hugine, Jr.  ...        R       2
# 3     AL  35762     1       5  Dr. Andrew Hugine, Jr.  ...        Z       0
# 4     AL  35762     1       5  Dr. Andrew Hugine, Jr.  ...        R       0
#
#    XHRUNKNW HRUNKNW  XHRNRALT  HRNRALT XHRNRALM HRNRALM XHRNRALW HRNRALW
# 0         R       1         R        0        R       0        R        0
# 1         R       0         R        0        R       0        R        0
# 2         R       0         R        0        R       0        R        0
# 3         Z       0         Z        0        Z       0        Z        0
# 4         R       0         R        0        R       0        R        0
#
# [5 rows x 137 columns]

# %%
furman = merged[merged['INSTNM'] == 'Furman University']
furman.head()
# Out:
#         UNITID             INSTNM             IALIAS                   ADDR  \
# 109423  218070  Furman University  Furman University  3300 Poinsett Highway
# 109424  218070  Furman University  Furman University  3300 Poinsett Highway
# 109425  218070  Furman University  Furman University  3300 Poinsett Highway
# 109426  218070  Furman University  Furman University  3300 Poinsett Highway
# 109427  218070  Furman University  Furman University  3300 Poinsett Highway
#
#               CITY STABBR         ZIP  FIPS  OBEREG      CHFNM  ... XHRUNKNM  \
# 109423  Greenville     SC  29613-6162    45       5  Elizabeth  ...        R
# 109424  Greenville     SC  29613-6162    45       5  Elizabeth  ...        R
# 109425  Greenville     SC  29613-6162    45       5  Elizabeth  ...        R
# 109426  Greenville     SC  29613-6162    45       5  Elizabeth  ...        Z
# 109427  Greenville     SC  29613-6162    45       5  Elizabeth  ...        Z
#
#        HRUNKNM  XHRUNKNW HRUNKNW  XHRNRALT  HRNRALT XHRNRALM HRNRALM XHRNRALW  \
# 109423       0         R       1         R       16        R      11        R
# 109424       0         R       0         R       11        R       7        R
# 109425       0         R       0         R       10        R       7        R
# 109426       0         Z       0         R        1        Z       0        R
# 109427       0         Z       0         Z        0        Z       0        Z
#
#        HRNRALW
# 109423        5
# 109424        4
# 109425        3
# 109426        1
# 109427        0
#
# [5 rows x 137 columns]

# %%
furman['OCCUPCAT'].value_counts()
# Out:
# 100    3
# 270    3
# 370    3
# 350    3
# 330    3
# 320    3
# 200    3
# 300    3
# 250    3
# 210    3
# 263    2
# 262    2
# 310    2
# 260    2
# 340    2
# 220    2
# 380    2
# 390    2
# Name: OCCUPCAT, dtype: int64

# %%
merged['STAFFCAT'].value_counts()
# Out:
# 1100    5871
# 2100    5863
# 1200    5808
# 1210    5797
# 1300    5640
#         ...
# 3261     251
# 3230     234
# 1264     220
# 2264     132
# 3264     111
# Name: STAFFCAT, Length: 70, dtype: int64
